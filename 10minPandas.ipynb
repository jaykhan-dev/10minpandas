# %% [markdown]
# <a href="https://colab.research.google.com/github/jaykhan-dev/10minpandas/blob/main/10minPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20210101", periods=6)
dates
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2021-01-01 -0.076113  0.787259  1.938659 -0.434284
# 2021-01-02 -1.150285 -0.569169  0.112503 -0.494936
# 2021-01-03 -0.736032  1.315885 -0.816381 -2.192959
# 2021-01-04 -1.902561  0.083556 -0.458841 -0.070445
# 2021-01-05 -0.541681 -0.177186  2.219426 -0.564594
# 2021-01-06  1.179681  0.038642 -0.397436  1.079290

# %%
df2 = pd.DataFrame({
    "A": 1.0,
    "B": pd.Timestamp("20210102"),
    "C": pd.Series(1, index=list(range(4)), dtype="float32"),
    "D": np.array([3] * 4, dtype="int32"),
    "E": pd.Categorical(["test", "train", "test", "train"]),
    "F": "foo",
})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2021-01-02  1.0  3   test  foo
# 1  1.0 2021-01-02  1.0  3  train  foo
# 2  1.0 2021-01-02  1.0  3   test  foo
# 3  1.0 2021-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2021-01-01 -0.076113  0.787259  1.938659 -0.434284
# 2021-01-02 -1.150285 -0.569169  0.112503 -0.494936
# 2021-01-03 -0.736032  1.315885 -0.816381 -2.192959
# 2021-01-04 -1.902561  0.083556 -0.458841 -0.070445
# 2021-01-05 -0.541681 -0.177186  2.219426 -0.564594

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2021-01-04 -1.902561  0.083556 -0.458841 -0.070445
# 2021-01-05 -0.541681 -0.177186  2.219426 -0.564594
# 2021-01-06  1.179681  0.038642 -0.397436  1.079290

# %%
df.index
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.07611318,  0.78725926,  1.93865874, -0.43428416],
#        [-1.15028531, -0.56916923,  0.11250348, -0.4949361 ],
#        [-0.73603213,  1.31588456, -0.81638096, -2.19295938],
#        [-1.90256138,  0.08355587, -0.45884104, -0.07044528],
#        [-0.54168076, -0.1771855 ,  2.21942629, -0.56459372],
#        [ 1.17968147,  0.03864226, -0.39743571,  1.07928985]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2021-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2021-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2021-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2021-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.537832  0.246498  0.432988 -0.446321
# std    1.043065  0.685651  1.312021  1.052237
# min   -1.902561 -0.569169 -0.816381 -2.192959
# 25%   -1.046722 -0.123229 -0.443490 -0.547179
# 50%   -0.638856  0.061099 -0.142466 -0.464610
# 75%   -0.192505  0.611333  1.482120 -0.161405
# max    1.179681  1.315885  2.219426  1.079290

# %%
df.T
# Out:
#    2021-01-01  2021-01-02  2021-01-03  2021-01-04  2021-01-05  2021-01-06
# A   -0.076113   -1.150285   -0.736032   -1.902561   -0.541681    1.179681
# B    0.787259   -0.569169    1.315885    0.083556   -0.177186    0.038642
# C    1.938659    0.112503   -0.816381   -0.458841    2.219426   -0.397436
# D   -0.434284   -0.494936   -2.192959   -0.070445   -0.564594    1.079290

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2021-01-01 -0.434284  1.938659  0.787259 -0.076113
# 2021-01-02 -0.494936  0.112503 -0.569169 -1.150285
# 2021-01-03 -2.192959 -0.816381  1.315885 -0.736032
# 2021-01-04 -0.070445 -0.458841  0.083556 -1.902561
# 2021-01-05 -0.564594  2.219426 -0.177186 -0.541681
# 2021-01-06  1.079290 -0.397436  0.038642  1.179681

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2021-01-02 -1.150285 -0.569169  0.112503 -0.494936
# 2021-01-05 -0.541681 -0.177186  2.219426 -0.564594
# 2021-01-06  1.179681  0.038642 -0.397436  1.079290
# 2021-01-04 -1.902561  0.083556 -0.458841 -0.070445
# 2021-01-01 -0.076113  0.787259  1.938659 -0.434284
# 2021-01-03 -0.736032  1.315885 -0.816381 -2.192959

# %%
df["A"]
# Out:
# 2021-01-01   -0.076113
# 2021-01-02   -1.150285
# 2021-01-03   -0.736032
# 2021-01-04   -1.902561
# 2021-01-05   -0.541681
# 2021-01-06    1.179681
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2021-01-01 -0.076113  0.787259  1.938659 -0.434284
# 2021-01-02 -1.150285 -0.569169  0.112503 -0.494936
# 2021-01-03 -0.736032  1.315885 -0.816381 -2.192959

# %%
df["20210102":"20210104"]
# Out:
#                    A         B         C         D
# 2021-01-02 -1.150285 -0.569169  0.112503 -0.494936
# 2021-01-03 -0.736032  1.315885 -0.816381 -2.192959
# 2021-01-04 -1.902561  0.083556 -0.458841 -0.070445

# %%
df.loc[dates[0]]
# Out:
# A   -0.076113
# B    0.787259
# C    1.938659
# D   -0.434284
# Name: 2021-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2021-01-01 -0.076113  0.787259
# 2021-01-02 -1.150285 -0.569169
# 2021-01-03 -0.736032  1.315885
# 2021-01-04 -1.902561  0.083556
# 2021-01-05 -0.541681 -0.177186
# 2021-01-06  1.179681  0.038642

# %%
df.loc["20210102":"20210104", ["A", "B"]]
# Out:
#                    A         B
# 2021-01-02 -1.150285 -0.569169
# 2021-01-03 -0.736032  1.315885
# 2021-01-04 -1.902561  0.083556

# %%
df.loc["20210102", ["A", "B"]]
# Out:
# A   -1.150285
# B   -0.569169
# Name: 2021-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0], "A"]
# Out:
# -0.0761131809664938

# %%
df.at[dates[0], "A"]
# Out:
# -0.0761131809664938

# %%
df.iloc[3]
# Out:
# A   -1.902561
# B    0.083556
# C   -0.458841
# D   -0.070445
# Name: 2021-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2021-01-04 -1.902561  0.083556
# 2021-01-05 -0.541681 -0.177186

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2021-01-02 -1.150285  0.112503
# 2021-01-03 -0.736032 -0.816381
# 2021-01-05 -0.541681  2.219426

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2021-01-02 -1.150285 -0.569169  0.112503 -0.494936
# 2021-01-03 -0.736032  1.315885 -0.816381 -2.192959

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2021-01-01  0.787259  1.938659
# 2021-01-02 -0.569169  0.112503
# 2021-01-03  1.315885 -0.816381
# 2021-01-04  0.083556 -0.458841
# 2021-01-05 -0.177186  2.219426
# 2021-01-06  0.038642 -0.397436

# %%
df.iloc[1, 1]
# Out:
# -0.5691692274626109

# %%
df.iat[1, 1]
# Out:
# -0.5691692274626109

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C        D
# 2021-01-06  1.179681  0.038642 -0.397436  1.07929

# %%
df[df > 0]
# Out:
#                    A         B         C        D
# 2021-01-01       NaN  0.787259  1.938659      NaN
# 2021-01-02       NaN       NaN  0.112503      NaN
# 2021-01-03       NaN  1.315885       NaN      NaN
# 2021-01-04       NaN  0.083556       NaN      NaN
# 2021-01-05       NaN       NaN  2.219426      NaN
# 2021-01-06  1.179681  0.038642       NaN  1.07929

# %%
df2= df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2021-01-01 -0.076113  0.787259  1.938659 -0.434284    one
# 2021-01-02 -1.150285 -0.569169  0.112503 -0.494936    one
# 2021-01-03 -0.736032  1.315885 -0.816381 -2.192959    two
# 2021-01-04 -1.902561  0.083556 -0.458841 -0.070445  three
# 2021-01-05 -0.541681 -0.177186  2.219426 -0.564594   four
# 2021-01-06  1.179681  0.038642 -0.397436  1.079290  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2021-01-03 -0.736032  1.315885 -0.816381 -2.192959   two
# 2021-01-05 -0.541681 -0.177186  2.219426 -0.564594  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20210102", periods=6))
s1
# Out:
# 2021-01-02    1
# 2021-01-03    2
# 2021-01-04    3
# 2021-01-05    4
# 2021-01-06    5
# 2021-01-07    6
# Freq: D, dtype: int64

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "F"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C  D  F
# 2021-01-01  0.000000  0.000000  1.938659  5  5
# 2021-01-02 -1.150285 -0.569169  0.112503  5  5
# 2021-01-03 -0.736032  1.315885 -0.816381  5  5
# 2021-01-04 -1.902561  0.083556 -0.458841  5  5
# 2021-01-05 -0.541681 -0.177186  2.219426  5  5
# 2021-01-06  1.179681  0.038642 -0.397436  5  5

# %%
df2 = df.copy()
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C  D  F
# 2021-01-01  0.000000  0.000000 -1.938659 -5 -5
# 2021-01-02 -1.150285 -0.569169 -0.112503 -5 -5
# 2021-01-03 -0.736032 -1.315885 -0.816381 -5 -5
# 2021-01-04 -1.902561 -0.083556 -0.458841 -5 -5
# 2021-01-05 -0.541681 -0.177186 -2.219426 -5 -5
# 2021-01-06 -1.179681 -0.038642 -0.397436 -5 -5

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1
df1
# Out:
#                    A         B         C  D  F    E
# 2021-01-01  0.000000  0.000000  1.938659  5  5  1.0
# 2021-01-02 -1.150285 -0.569169  0.112503  5  5  1.0
# 2021-01-03 -0.736032  1.315885 -0.816381  5  5  NaN
# 2021-01-04 -1.902561  0.083556 -0.458841  5  5  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C  D  F    E
# 2021-01-01  0.000000  0.000000  1.938659  5  5  1.0
# 2021-01-02 -1.150285 -0.569169  0.112503  5  5  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D  F    E
# 2021-01-01  0.000000  0.000000  1.938659  5  5  1.0
# 2021-01-02 -1.150285 -0.569169  0.112503  5  5  1.0
# 2021-01-03 -0.736032  1.315885 -0.816381  5  5  5.0
# 2021-01-04 -1.902561  0.083556 -0.458841  5  5  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2021-01-01  False  False  False  False  False  False
# 2021-01-02  False  False  False  False  False  False
# 2021-01-03  False  False  False  False  False   True
# 2021-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -0.525146
# B    0.115288
# C    0.432988
# D    5.000000
# F    5.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2021-01-01    2.387732
# 2021-01-02    1.678610
# 2021-01-03    1.952694
# 2021-01-04    1.544431
# 2021-01-05    2.300112
# 2021-01-06    2.164178
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2021-01-01    NaN
# 2021-01-02    NaN
# 2021-01-03    1.0
# 2021-01-04    3.0
# 2021-01-05    5.0
# 2021-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2021-01-01       NaN       NaN       NaN  NaN  NaN
# 2021-01-02       NaN       NaN       NaN  NaN  NaN
# 2021-01-03 -1.736032  0.315885 -1.816381  4.0  4.0
# 2021-01-04 -4.902561 -2.916444 -3.458841  2.0  2.0
# 2021-01-05 -5.541681 -5.177186 -2.780574  0.0  0.0
# 2021-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D   F
# 2021-01-01  0.000000  0.000000  1.938659   5   5
# 2021-01-02 -1.150285 -0.569169  2.051162  10  10
# 2021-01-03 -1.886317  0.746715  1.234781  15  15
# 2021-01-04 -3.788879  0.830271  0.775940  20  20
# 2021-01-05 -4.330560  0.653086  2.995367  25  25
# 2021-01-06 -3.150878  0.691728  2.597931  30  30

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    3.082243
# B    1.885054
# C    3.035807
# D    0.000000
# F    0.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    3
# 1    0
# 2    6
# 3    1
# 4    6
# 5    5
# 6    3
# 7    6
# 8    3
# 9    4
# dtype: int64

# %%
s.value_counts()
# Out:
# 6    3
# 3    3
# 5    1
# 4    1
# 1    1
# 0    1
# dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Khan", "Khaan", np.nan, "Jay", "kiki", "blue"])
s.str.lower()
# Out:
# 0        a
# 1        b
# 2        c
# 3     khan
# 4    khaan
# 5      NaN
# 6      jay
# 7     kiki
# 8     blue
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.557490 -0.606198 -0.754028  0.649866
# 1  1.038595 -1.758380 -0.085734  0.211046
# 2 -0.706415  0.504831 -0.941022  0.630367
# 3 -0.595114  0.379487 -1.835049 -0.236938
# 4 -0.485260  1.908037  0.299718 -0.509126
# 5 -1.281265 -1.226895 -1.395945  0.597158
# 6  0.405579 -0.310842  1.588275 -0.143158
# 7 -0.663925 -1.165461  0.879004 -0.022291
# 8 -0.354484 -0.662316 -0.501180 -0.505790
# 9 -1.932615 -1.084827 -0.166644  0.063850

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.557490 -0.606198 -0.754028  0.649866
# 1  1.038595 -1.758380 -0.085734  0.211046
# 2 -0.706415  0.504831 -0.941022  0.630367
# 3 -0.595114  0.379487 -1.835049 -0.236938
# 4 -0.485260  1.908037  0.299718 -0.509126
# 5 -1.281265 -1.226895 -1.395945  0.597158
# 6  0.405579 -0.310842  1.588275 -0.143158
# 7 -0.663925 -1.165461  0.879004 -0.022291
# 8 -0.354484 -0.662316 -0.501180 -0.505790
# 9 -1.932615 -1.084827 -0.166644  0.063850

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)
df
# Out:
#      A      B         C         D
# 0  foo    one  0.267884  0.021273
# 1  bar    one  0.051185 -1.041089
# 2  foo    two  1.140292 -1.143773
# 3  bar  three -0.799783  1.358778
# 4  foo    two  2.447190 -0.312060
# 5  bar    two -0.091859  0.225144
# 6  foo    one -0.872180  1.131779
# 7  foo  three  0.001222  0.152340

# %%
df.groupby("A").sum()
# Out:
#             C         D
# A
# bar -0.840456  0.542833
# foo  2.984407 -0.150441

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    0.051185 -1.041089
#     three -0.799783  1.358778
#     two   -0.091859  0.225144
# foo one   -0.604297  1.153052
#     three  0.001222  0.152340
#     two    3.587482 -1.455833

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)
index = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     1.867256  1.423105
#       two     0.842536  0.769602
# baz   one    -2.376542  0.204542
#       two    -1.637180 -0.662620

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    1.867256
#                B    1.423105
#        two     A    0.842536
#                B    0.769602
# baz    one     A   -2.376542
#                B    0.204542
#        two     A   -1.637180
#                B   -0.662620
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     1.867256  1.423105
#       two     0.842536  0.769602
# baz   one    -2.376542  0.204542
#       two    -1.637180 -0.662620

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  1.867256  0.842536
#       B  1.423105  0.769602
# baz   A -2.376542 -1.637180
#       B  0.204542 -0.662620

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  1.867256 -2.376542
#        B  1.423105  0.204542
# two    A  0.842536 -1.637180
#        B  0.769602 -0.662620

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.329612 -0.203696
# 1     one  B  foo  1.979089  1.455995
# 2     two  C  foo  0.326816  0.300507
# 3   three  A  bar -0.926020 -1.462032
# 4     one  B  bar  1.556572  0.397816
# 5     one  C  bar  1.111126 -0.808120
# 6     two  A  foo  1.658637  0.904932
# 7   three  B  foo  1.317238  0.828631
# 8     one  C  foo -0.635032  0.449990
# 9     one  A  bar  0.267249 -0.060859
# 10    two  B  bar  0.242705 -0.374312
# 11  three  C  bar -0.168017 -0.755096

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.267249 -0.329612
#       B  1.556572  1.979089
#       C  1.111126 -0.635032
# three A -0.926020       NaN
#       B       NaN  1.317238
#       C -0.168017       NaN
# two   A       NaN  1.658637
#       B  0.242705       NaN
#       C       NaN  0.326816

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="S")
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample("5Min").sum()
# Out:
# 2012-01-01    24851
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06    0.263891
# 2012-03-07    1.748624
# 2012-03-08   -0.133483
# 2012-03-09   -0.659960
# 2012-03-10    1.618378
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.263891
# 2012-03-07 00:00:00+00:00    1.748624
# 2012-03-08 00:00:00+00:00   -0.133483
# 2012-03-09 00:00:00+00:00   -0.659960
# 2012-03-10 00:00:00+00:00    1.618378
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00    0.263891
# 2012-03-06 19:00:00-05:00    1.748624
# 2012-03-07 19:00:00-05:00   -0.133483
# 2012-03-08 19:00:00-05:00   -0.659960
# 2012-03-09 19:00:00-05:00    1.618378
# Freq: D, dtype: float64

# %%
rng = pd.date_range("1/1/2012", periods=5, freq="M")
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31    2.238446
# 2012-02-29   -0.417630
# 2012-03-31   -0.226579
# 2012-04-30    0.708475
# 2012-05-31   -0.564809
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01    2.238446
# 2012-02   -0.417630
# 2012-03   -0.226579
# 2012-04    0.708475
# 2012-05   -0.564809
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    2.238446
# 2012-02-01   -0.417630
# 2012-03-01   -0.226579
# 2012-04-01    0.708475
# 2012-05-01   -0.564809
# Freq: MS, dtype: float64

# %%
prng = pd.period_range("1990Q1", "2000Q4", freq="Q-NOV")
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq("M", "e") + 1).asfreq("H", "s") + 9
ts.head()
# Out:
# 1990-03-01 09:00    1.343259
# 1990-06-01 09:00   -1.072716
# 1990-09-01 09:00    1.940753
# 1990-12-01 09:00   -1.056281
# 1991-03-01 09:00   -0.784522
# Freq: H, dtype: float64

# %%
df = pd.DataFrame(
    {
        "id": [1, 2, 3, 4, 5, 6],
        "raw_grade": ["a", "b", "b", "a", "a", "e"]
    }
)

df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): ['very good', 'good', 'very bad']

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)
df = df.cumsum()
plt.figure();
df.plot();
plt.legend(loc='best');
